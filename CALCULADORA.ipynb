# %%
print("CALCULADORA BÁSICA")
'''
Calculadora para operaciones sencillas: Suma, Resta, Multiplicación,División.
'''
print()
print("Digite: 1,Sumar, ó + ,para Sumar")
print("Digite: 2, Restar, ó - para Restar")
print("Digite: 3,Multiplicar, ó *, para Multiplicar")
print("Digite: 4,Dividir, ó /para Dividir")
print()
option=input("Ingrese la Operación a Realizar")
number_one=float(input("Ingrese un número "))
number_two=float(input("Ingrese un número "))
if option=="1" or option=="Sumar" or option=="+":
  print("Sumaremos los valores",number_one+number_two)
if option=="2" or option=="Restar" or option=="-":
  print("Restaremos los valores",number_one-number_two)
if option=="3" or option=="Multiplicar" or option=="*":
  print("Multiplicaremos los valores",number_one*number_two)

if option=="4" or option=="Dividir" or option=="/":
  if number_two!=0:
    print("Dividiremos los valores",number_one/number_two)
  else:
    print("No se puede dividir entre 0")
# Out:
# CALCULADORA BÁSICA
#
# Digite: 1,Sumar, ó + ,para Sumar
# Digite: 2, Restar, ó - para Restar
# Digite: 3,Multiplicar, ó *, para Multiplicar
# Digite: 4,Dividir, ó /para Dividir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-f010303b56d3> in <cell line: 0>()
#       9 print("Digite: 4,Dividir, ó /para Dividir")
#      10 print()
# ---> 11 option=input("Ingrese la Operación a Realizar")
#      12 number_one=float(input("Ingrese un número "))
#      13 number_two=float(input("Ingrese un número "))
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %% [markdown]
# # CALCULADORA CIENTIFICA

# %%
import math
print("CALCULADORA CIENTIFICA")
'''
Calculadora Científica.
'''
option="0"
while option!= 11:
  print()
  print("Digite: 1,Sumar, ó + ,para Sumar")
  print("Digite: 2, Restar, ó - para Restar")
  print("Digite: 3,Multiplicar, ó *, para Multiplicar")
  print("Digite: 4,Dividir, ó /para Dividir")
  print("Digite: 5,para Elevar")
  print("Digite: 6,para encontrar la raiz cuadrada")
  print("Digite: 7,para encontrar la raiz cubica")
  print("Digite: 8,para Tangente")
  print("Digite: 9,para coseno")
  print("Digite: 10, para seno")
  print("Digite: 11, para salir")

  option=input("Ingrese la Operación a Realizar")

  if option >="1" and option <="10":
    number_one=float(input("Ingrese un número "))
    number_two=float(input("Ingrese un número "))
    if option=="1" or option=="Sumar" or option=="+":
      print("Sumaremos los valores",number_one+number_two)
    if option=="2" or option=="Restar" or option=="-":
      print("Restaremos los valores",number_one-number_two)
    if option=="3" or option=="Multiplicar" or option=="*":
      print("Multiplicaremos los valores",number_one*number_two)

    if option=="4" or option=="Dividir" or option=="/":
      if number_two!=0:
        print("Dividiremos los valores",number_one/number_two)
      else:
        print("No se puede dividir entre 0")


    if option=="5":
      r=pow(number_one,number_two)
      print("El resultado es:",r)
    if option>"5" and option<"10":
      number_one=float(input("Ingrese el numero"))
    if option=="6":
      r=math.sqrt(number_one)
      print("El resultado de la raiz cuadrada es ")
    if option=="7":
      r=math.cbrt(number_one)
      print("El resultado de la raizs cubica es ")
    if option=="8":
      r=math.tan(number_one)

  if

  break
  else:
    print("Saliste de la calculadora")
# Out:
# CALCULADORA CIENTIFICA
#
# Digite: 1,Sumar, ó + ,para Sumar
# Digite: 2, Restar, ó - para Restar
# Digite: 3,Multiplicar, ó *, para Multiplicar
# Digite: 4,Dividir, ó /para Dividir
# Digite: 5,para Elevar
# Digite: 6,para encontrar la raiz cuadrada
# Digite: 7,para encontrar la raiz cubica
# Digite: 8,para Tangente
# Digite: 9,para coseno
# Digite: 10, para seno
# Ingrese la Operación a Realizar11
# Saliste de la calculadora
#
# Digite: 1,Sumar, ó + ,para Sumar
# Digite: 2, Restar, ó - para Restar
# Digite: 3,Multiplicar, ó *, para Multiplicar
# Digite: 4,Dividir, ó /para Dividir
# Digite: 5,para Elevar
# Digite: 6,para encontrar la raiz cuadrada
# Digite: 7,para encontrar la raiz cubica
# Digite: 8,para Tangente
# Digite: 9,para coseno
# Digite: 10, para seno
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-667fdab97e00> in <cell line: 0>()
# ...
