# %%
#1.lista
mercado_de_frutas=["Fresas","Uvas","Frambuesas","Arándanos","Ciruelas_Rojas"]
print(mercado_de_frutas)
# Out:
# ['Fresas', 'Uvas', 'Frambuesas', 'Arándanos', 'Ciruelas_Rojas']

# %%
#2.Tupla
estudiante_de_pregrado=("Juan_Narvaes","Maria_Paz","Felipe_Burbano","Ezequiel_Grajales")
print(estudiante_de_pregrado)
# Out:
# ('Juan_Narvaes', 'Maria_Paz', 'Felipe_Burbano', 'Ezequiel_Grajales')

# %%
#3.Conjunto
figuras_geométricas={"círculo","cuadrado","rectangulo","cilindro","cono","óvalo","pentágono"}
print(figuras_geométricas)
# Out:
# {'cuadrado', 'óvalo', 'rectangulo', 'círculo', 'pentágono', 'cono', 'cilindro'}

# %%
#4.Diccionario
animales_de_granja_en_ingles={"vaca":"cow","puerco":"pig","pollo":"chicken","caballo":"horse","pato":"duck"}
print(animales_de_granja_en_ingles)
# Out:
# {'vaca': 'cow', 'puerco': 'pig', 'pollo': 'chicken', 'caballo': 'horse', 'pato': 'duck'}
